# %% [markdown]
# # Deportation's Fallout: Evidence from Denmark
# ## Running Analysis
#
# This notebook walks you through the creation of the results created in `/scripts/run_analysis.py` step-by-step, incl. the [appendix](#Appendix).
#
# For this notebook to work, make sure the project is installed *including optional dependencies*:
#
# In the terminal:
# ```
# pip install -e .[notebooks]
# ```

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Dependencies
import deportations_fallout.results.figures as figs
import deportations_fallout.results.tables as tabs

# Configuration
from deportations_fallout.config import PATHS
paths = PATHS

# %% [markdown]
# ### Figure 1: Deportation Orders Over Time

# %%
fig, _ = figs.figure_1()
fig.savefig(paths.figures / "fig1.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# ### Table 1: Descriptives of Spouses by Deportation Order

# %%
tbl = tabs.table_1()
tbl.to_html(paths.tables/"tab1.html")

# %% [markdown]
# ### Figure 2: Spouses' Employment: Trends and Estimation Results

# %%
fig, _ = figs.figure_2()
fig.savefig(paths.figures / "fig2.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# ### Table 2: Static Estimations

# %%
tbl = tabs.table_2()
tbl.to_html(paths.tables/"tab2.html", escape=False)

# %% [markdown]
# ### Figure 3: Other Labour Market Outcomes: Trends and Estimation Results

# %%
fig, _ = figs.figure_3()
fig.savefig(paths.figures / "fig3.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# ### Figure 4: Migrations Out of Denmark

# %%
fig, _ = figs.figure_4()
fig.savefig(paths.figures / "fig4.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# ### Table 3: Descriptives of Spouses by Deportation Order and Migration

# %%
tbl = tabs.table_3()
tbl.to_html(paths.tables/"tab3.html")

# %% [markdown]
# ### Figure 5: Attrition: Manski Bounds on Main Results
#
# Includes test of informative attrition.

# %%
fig, _ = figs.figure_5()
fig.savefig(paths.figures/"fig5.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display
# Out:
# Informative attrition test:
#      Coef.: 0.083; p-value: 0.004

# %% [markdown]
# ### Figure 6: Attrition: Spouses' Labour Market Outcomes, ATT-Rs

# %%
fig, ax = figs.figure_6()
fig.savefig(paths.figures/"fig6.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# ### Figure 7: IPCW and kNN

# %%
fig, ax = figs.figure_7()
fig.savefig(paths.figures/"fig7.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# ### Figure 8: Migration Patterns by Grounds for Residence

# %%
fig, ax = figs.figure_8()
fig.savefig(paths.figures/"fig8.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# ### Figure 9: Main Results by Grounds for Residence

# %%
fig, ax = figs.figure_9()
fig.savefig(paths.figures/"fig9.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# ## Appendix

# %% [markdown]
# ### Appendix A

# %% [markdown]
# #### Table A1: Descriptives of Female Spouses and Female Foreign-Born Population

# %%
tbl = tabs.table_a1()
tbl.to_html(paths.tables/"tabA1.html")

# %% [markdown]
# #### Figure A1: Main Results for Unconditional Prison Sentences Only

# %%
fig, _ = figs.figure_a1()
fig.savefig(paths.figures/"figA1.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# ### Appendix B

# %% [markdown]
# #### Figure B1: Deportation Risk by Residence Seniority

# %%
fig, _ = figs.figure_b1()
fig.savefig(paths.figures/"figB1.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# #### Table B1: Test of Change in Sample Size Around Cutoff
#
# Also generates data for McCrary test in STATA.

# %%
tbl, mccrary = tabs.table_b1()
tbl.to_html(paths.tables/"tabB1.html", escape=False)
mccrary.to_stata(paths.temp / "mccrary.dta", write_index=False)

# %% [markdown]
# #### Table B2: Unconditional Balancing Test

# %%
tbl = tabs.table_b2()
tbl.to_html(paths.tables/"tabB2.html", escape=False)

# %% [markdown]
# #### Table B3: Conditional Balancing Test

# %%
tbl = tabs.table_b3()
tbl.to_html(paths.tables/"tabB3.html", escape=False)

# %% [markdown]
# #### Figure B2: Spouses' Employment: Regression Discontinuity

# %%
fig, ax = figs.figure_b2()
fig.savefig(paths.figures/"figB2.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# ### Appendix C

# %% [markdown]
# #### Table C1: Deportation Probabilities by Court

# %%
tbl = tabs.table_c1()
tbl.to_html(paths.tables/"tabC1.html")

# %% [markdown]
# #### Figure C1: Residency Seniority by Deportation Order

# %%
fig, ax = figs.figure_c1()
fig.savefig(paths.figures/"figC1.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display

# %% [markdown]
# #### Figure C2: Types of Crimes by Deportation Order

# %%
fig, ax = figs.figure_c2()
fig.savefig(paths.figures/"figC2.tif", pil_kwargs={"compression": "tiff_lzw"})

# plt.close("all") # Control figure display
