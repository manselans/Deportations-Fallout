# %% [markdown]
# # Appendix walkthrough
#
# This notebook is a step-by-step walkthorugh of the appendix pipeline, `scripts/appendix.py`.
#
# Runs:
# 1. `analysis/appendix_a.py`
# 2. `analysis/appendix_b.py`
# 3. `analysis/appendix_c.py`

# %% [markdown]
# ## Appendix A
#
# Step: `analysis/appendix_a.py`
#
# Creates Table A1 and Figure A1. These are fairly straight forward and not discussed further here.

# %%
from depo_paper.analysis.appendix_a import run as run_appendix_a
run_appendix_a()

# %% [markdown]
# ## Appendix B
#
# Step: `analysis/appendix_b.py`
#
# - Figures B1 and B2 and Tables B1, B2 and B3
#
# ### Purpose
# Utilize a fuzzy regression dicontinuity (RD) design based on residency seniority rules in relation to deportation orders:
# - Test and visualize identification assumptions behind the fuzzy RD.
# - Regress and visualize results.
#
# ### What happens
# - Shows discontinuity (Figure B1)
# - Conducts traditional assumption testing:
#     - Test of change in sample size around cutoff (results in Table B1)
#     - Conditional and unconditional balancing tests (results in Table B2 and B3)
# - Saves data for use in a density discontinuity test tied to Stata code in `src/depo_paper/mccrary.do`.
# - Runs a fuzzy RD regression (results in Figure B2)

# %%
from depo_paper.analysis.appendix_b import run as run_appendix_b
run_appendix_b()

# %% [markdown]
# ## Appendix C
#
# Step: `analysis/appendix_c.py`
#
# - Table C1 and Figures C1 and C2
#
# ### Purpose
# Additional descriptives.
#
# ### What happens
# - Compare probabilities of deportations across courts (results in Table C1).
# - Compare treatment and control groups on:
#     - Residency seniority at time of conviction (Figure C1).
#     - Types of crime behind convitcion (Figure C2).

# %%
from depo_paper.analysis.appendix_c import run as run_appendix_c
run_appendix_c()
